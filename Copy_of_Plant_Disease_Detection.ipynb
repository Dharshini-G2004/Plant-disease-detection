# %% [markdown]
# ### Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
import os
from os import listdir
from PIL import Image
import tensorflow as tf
from keras.preprocessing import image
from tensorflow. keras.utils import img_to_array, array_to_img
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dropout, Dense
from sklearn. model_selection import train_test_split
from keras.models import model_from_json
from keras.utils import to_categorical
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 10
#       8 from os import listdir
#       9 from PIL import Image
# ---> 10 import tensorflow as tf
#      11 from keras.preprocessing import image
#      12 from tensorflow. keras.utils import img_to_array, array_to_img
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\__init__.py:40
#      37 _os.environ.setdefault("ENABLE_RUNTIME_UPTIME_TELEMETRY", "1")
#      39 # Do not remove this line; See https://github.com/tensorflow/tensorflow/issues/42596
# ---> 40 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow  # pylint: disable=unused-import
#      41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import KerasLazyLoader as _KerasLazyLoader
#
# ModuleNotFoundError: No module named 'tensorflow.python'

# %%
print(tf. __version__)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# 2.18.0
# Mounted at /content/drive

# %% [markdown]
# ### Defining the path of dataset directory

# %%
dataset_path = "/content/drive/My Drive/AIML/Plant-Disease-Detection/DataSet"

# %% [markdown]
# ### Visualizing the images and Resize images

# %%
# Plotting 12 images to check dataset

plt.figure(figsize = (12, 12))
dataset_path = "/content/drive/My Drive/AIML/Plant-Disease-Detection/DataSet/Corn__Common_Rust"

for i in range(1, 17):
    plt.subplot(4, 4, i)
    plt.tight_layout()
    rand_img = imread(dataset_path +'/'+ random.choice(sorted(os.listdir(dataset_path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10) # width of image
    plt.ylabel(rand_img.shape[0], fontsize = 10) # height of image

# %% [markdown]
# ### Convert the images into a Numpy array and normalize them

# %%
# Converting Images to array

def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, (256, 256))
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
dataset_path = r"/content/drive/My Drive/AIML/Plant-Disease-Detection/DataSet"
labels = os.listdir(dataset_path)

print(labels)
# Out:
# ['Corn__Common_Rust', 'Potato___Early_blight', 'Tomato___Bacterial_spot']

# %%
dataset_path = r"/content/drive/My Drive/AIML/Plant-Disease-Detection/DataSet"
root_dir = listdir(dataset_path)
image_list, label_list = [], []
all_labels = ['Corn__Common_Rust', 'Potato-Early_blight', 'Tomato__Bacterial_spot']
binary_labels = [0, 1, 2]
temp = -1

# Reading and converting image to numpy array

for directory in root_dir:
  plant_image_list = listdir(f"{dataset_path}/{directory}")
  temp += 1
  for files in plant_image_list:
    image_path = f"{dataset_path}/{directory}/{files}"
    image_list.append(convert_image_to_array(image_path))
    label_list.append(binary_labels[temp])

# %% [markdown]
# ### Visualize the class count and Check for class imbalance

# %%
# Visualize the number of classes count

label_counts = pd.DataFrame(label_list).value_counts()
label_counts.head()
# Out:
# 0
# 2    310
# 0    300
# 1    300
# Name: count, dtype: int64

# %%
# it is a balanced dataset as we can see

# %%
# Next we will observe the shape of the image.

image_list[0].shape
# Out:
# (256, 256, 3)

# %%
# Checking the total number of the images which is the length of the labels list.

label_list = np.array(label_list)
label_list.shape
# Out:
# (910,)

# %% [markdown]
# ### Splitting the dataset into train, validate and test sets

# %%
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %%
# Now we will normalize the dataset of our images. As pixel values ranges from 0 to 255 so we will divide each image pixel with 255 to normalize the dataset.

x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape(-1, 256, 256, 3)
x_test = x_test.reshape(-1, 256, 256, 3)

# %% [markdown]
# ### Performing one-hot encoding on target variable

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# ### Creating the model architecture, compile the model and then fit it using the training data

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding = "same",input_shape = (256, 256, 3), activation = "relu"))
model.add(MaxPooling2D(pool_size = (3, 3)))
model.add(Conv2D(16, (3, 3), padding = "same", activation = "relu"))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 43s 7s/step - accuracy: 0.9788 - loss: 0.0974 - val_accuracy: 0.9795 - val_loss: 0.0890
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 7s/step - accuracy: 0.9806 - loss: 0.0981 - val_accuracy: 0.9795 - val_loss: 0.0888
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 48s 7s/step - accuracy: 0.9838 - loss: 0.0911 - val_accuracy: 0.9863 - val_loss: 0.0782
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 76s 7s/step - accuracy: 0.9776 - loss: 0.0882 - val_accuracy: 0.9795 - val_loss: 0.0776
# Epoch 31/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 37s 7s/step - accuracy: 0.9866 - loss: 0.0774 - val_accuracy: 0.9932 - val_loss: 0.0799
# Epoch 32/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 41s 7s/step - accuracy: 0.9838 - loss: 0.0763 - val_accuracy: 0.9795 - val_loss: 0.0723
# Epoch 33/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 42s 7s/step - accuracy: 0.9842 - loss: 0.0770 - val_accuracy: 0.9932 - val_loss: 0.0724
# Epoch 34/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 41s 7s/step - accuracy: 0.9909 - loss: 0.0626 - val_accuracy: 1.0000 - val_loss: 0.0673
# Epoch 35/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 42s 6s/step - accuracy: 0.9901 - loss: 0.0619 - val_accuracy: 0.9932 - val_loss: 0.0645
# Epoch 36/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 40s 6s/step - accuracy: 0.9848 - loss: 0.0684 - val_accuracy: 0.9932 - val_loss: 0.0657
# Epoch 37/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 40s 7s/step - accuracy: 0.9855 - loss: 0.0606 - val_accuracy: 1.0000 - val_loss: 0.0568
# Epoch 38/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 41s 7s/step - accuracy: 0.9839 - loss: 0.0657 - val_accuracy: 0.9795 - val_loss: 0.0657
# Epoch 39/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 38s 8s/step - accuracy: 0.9886 - loss: 0.0588 - val_accuracy: 1.0000 - val_loss: 0.0530
# Epoch 40/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 7s/step - accuracy: 0.9894 - loss: 0.0579 - val_accuracy: 0.9932 - val_loss: 0.0598
# Epoch 41/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 41s 7s/step - accuracy: 0.9906 - loss: 0.0558 - val_accuracy: 0.9932 - val_loss: 0.0514
# Epoch 42/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 41s 7s/step - accuracy: 0.9887 - loss: 0.0558 - val_accuracy: 0.9932 - val_loss: 0.0479
# Epoch 43/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 50s 9s/step - accuracy: 0.9912 - loss: 0.0520 - val_accuracy: 0.9863 - val_loss: 0.0560
# Epoch 44/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 73s 7s/step - accuracy: 0.9946 - loss: 0.0409 - val_accuracy: 1.0000 - val_loss: 0.0431
# Epoch 45/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 41s 7s/step - accuracy: 0.9879 - loss: 0.0524 - val_accuracy: 0.9863 - val_loss: 0.0593
# Epoch 46/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 41s 7s/step - accuracy: 0.9965 - loss: 0.0411 - val_accuracy: 1.0000 - val_loss: 0.0409
# Epoch 47/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 43s 7s/step - accuracy: 0.9940 - loss: 0.0437 - val_accuracy: 1.0000 - val_loss: 0.0371
# Epoch 48/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 39s 7s/step - accuracy: 0.9943 - loss: 0.0372 - val_accuracy: 0.9932 - val_loss: 0.0447
# Epoch 49/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 41s 7s/step - accuracy: 0.9949 - loss: 0.0382 - val_accuracy: 1.0000 - val_loss: 0.0377
# Epoch 50/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.9981 - loss: 0.0351 - val_accuracy: 0.9932 - val_loss: 0.0398

# %%
model.save("/content/drive/My Drive/Plant-Disease-Detection/Model/plant_disease_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ### Plot the accuracy and loss against each epoch

# %%
# Plot the training history

plt.figure(figsize = (12, 5))
plt.plot(history.history['accuracy'], color = 'r')
plt.plot(history.history['val_accuracy'], color = 'b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %%
print("Calculating model accuracy")

scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1] * 100}")
# Out:
# Calculating model accuracy
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 519ms/step - accuracy: 0.9807 - loss: 0.0591
# Test Accuracy: 98.35164546966553

# %% [markdown]
# ### Make predictions on testing data

# %%
y_pred = model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ae883ac500a2> in <cell line: 0>()
# ----> 1 y_pred = model.predict(x_test)
#
# NameError: name 'model' is not defined

# %% [markdown]
# ### Visualizing the original and predicted labels for the test images

# %%
# Plotting image to compare

img = array_to_img(x_test[22])
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
# Finding max value from predition list and comaparing original value vs predicted

print("Originally : ", all_labels[np.argmax(y_test[11])])
print("Predicted : ", all_labels[np.argmax(y_pred[4])])
print(y_pred[2])
# Out:
# Originally :  Potato-Early_blight
# Predicted :  Potato-Early_blight
# [0.00136392 0.93208414 0.06655193]

# %%
for i in range(50):
    print (all_labels[np.argmax(y_test[i])], " ", all_labels[np.argmax(y_pred [1])])
# Out:
# Potato-Early_blight   Corn__Common_Rust
# Corn__Common_Rust   Corn__Common_Rust
# Potato-Early_blight   Corn__Common_Rust
# Tomato__Bacterial_spot   Corn__Common_Rust
# Potato-Early_blight   Corn__Common_Rust
# Corn__Common_Rust   Corn__Common_Rust
# Potato-Early_blight   Corn__Common_Rust
# Corn__Common_Rust   Corn__Common_Rust
# Tomato__Bacterial_spot   Corn__Common_Rust
# Tomato__Bacterial_spot   Corn__Common_Rust
# Potato-Early_blight   Corn__Common_Rust
# Potato-Early_blight   Corn__Common_Rust
# Corn__Common_Rust   Corn__Common_Rust
# Corn__Common_Rust   Corn__Common_Rust
# Potato-Early_blight   Corn__Common_Rust
# Potato-Early_blight   Corn__Common_Rust
# Potato-Early_blight   Corn__Common_Rust
# Corn__Common_Rust   Corn__Common_Rust
# Tomato__Bacterial_spot   Corn__Common_Rust
# Tomato__Bacterial_spot   Corn__Common_Rust
# Tomato__Bacterial_spot   Corn__Common_Rust
# Potato-Early_blight   Corn__Common_Rust
# Corn__Common_Rust   Corn__Common_Rust
# Tomato__Bacterial_spot   Corn__Common_Rust
# Potato-Early_blight   Corn__Common_Rust
# Tomato__Bacterial_spot   Corn__Common_Rust
# Potato-Early_blight   Corn__Common_Rust
# Potato-Early_blight   Corn__Common_Rust
# Corn__Common_Rust   Corn__Common_Rust
# Tomato__Bacterial_spot   Corn__Common_Rust
# Potato-Early_blight   Corn__Common_Rust
# Corn__Common_Rust   Corn__Common_Rust
# Corn__Common_Rust   Corn__Common_Rust
# Potato-Early_blight   Corn__Common_Rust
# Corn__Common_Rust   Corn__Common_Rust
# Tomato__Bacterial_spot   Corn__Common_Rust
# Corn__Common_Rust   Corn__Common_Rust
# Corn__Common_Rust   Corn__Common_Rust
# Corn__Common_Rust   Corn__Common_Rust
# Tomato__Bacterial_spot   Corn__Common_Rust
# Corn__Common_Rust   Corn__Common_Rust
# Tomato__Bacterial_spot   Corn__Common_Rust
# Potato-Early_blight   Corn__Common_Rust
# Corn__Common_Rust   Corn__Common_Rust
# Potato-Early_blight   Corn__Common_Rust
# Tomato__Bacterial_spot   Corn__Common_Rust
# Tomato__Bacterial_spot   Corn__Common_Rust
# Corn__Common_Rust   Corn__Common_Rust
# Tomato__Bacterial_spot   Corn__Common_Rust
# Corn__Common_Rust   Corn__Common_Rust
